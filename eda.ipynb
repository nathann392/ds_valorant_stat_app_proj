# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("player_data.csv")

# %%
df.head()
# Out:
#    rank  rating             name  score/round  damage/round  k/d_ratio  \
# 0     1    1153  SEN zekken#5193        266.3         173.6       1.40
# 1     2    1142      NRG s0m#NRG        251.9         160.7       1.32
# 2     3    1133  SEN dephh#yadig        230.6         152.4       1.16
# 3     4    1126    N4RRATE#JESUS        263.7         170.2       1.27
# 4     5    1104  100T Asuna#1111        261.5         168.2       1.29
#
#    hs_percentage(%)  win_percentage(%)  \
# 0              41.6               66.2
# 1              29.5               61.1
# 2              30.6               58.6
# 3              21.9               64.3
# 4              25.6               63.8
#
#                             top_agents(agent, hours)  \
# 0  [['Sova', '30'], ['Chamber', '15'], ['Raze', '...
# 1  [['Astra', '43'], ['Sova', '31'], ['Brimstone'...
# 2  [['Astra', '52'], ['Chamber', '30'], ['Viper',...
# 3  [['Raze', '22'], ['Chamber', '20'], ['Reyna', ...
# ...

# %%
df.columns
# Out:
# Index(['rank', 'rating', 'name', 'score/round', 'damage/round', 'k/d_ratio',
#        'hs_percentage(%)', 'win_percentage(%)', 'top_agents(agent, hours)',
#        'top_weapons(weapon, kills, hs%)'],
#       dtype='object')

# %%
df.describe()
# Out:
#              rank       rating  score/round  damage/round   k/d_ratio  \
# count  497.000000   497.000000   497.000000    497.000000  497.000000
# mean   258.460765   665.364185   227.306841    148.289135    1.108813
# std    150.284364   126.112845    22.179727     13.735445    0.129770
# min      1.000000   520.000000   174.000000    113.400000    0.820000
# 25%    128.000000   573.000000   212.200000    138.600000    1.020000
# 50%    258.000000   622.000000   225.500000    147.300000    1.080000
# 75%    386.000000   726.000000   238.100000    155.400000    1.190000
# max    553.000000  1153.000000   317.700000    209.500000    1.680000
#
#        hs_percentage(%)  win_percentage(%)
# count        497.000000         497.000000
# mean          27.550503          54.173239
# std            5.142388           6.169170
# min           11.500000          41.200000
# 25%           24.100000          50.200000
# 50%           27.200000          53.100000
# ...
